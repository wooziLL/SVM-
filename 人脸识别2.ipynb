# %%
import cv2
import dlib
import os
import sys
import random
# 存储位置
output_dir = 'D:/face/631907060410/4me' #采集人脸的路径：其中2***为人名（英文方式）方便对比，第二次编译时修改为3***，进行多人比对
size = 100
 
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# 改变图片的亮度与对比度
 
def relight(img, light=1, bias=0):
    w = img.shape[1]
    h = img.shape[0]
    #image = []
    for i in range(0,w):
        for j in range(0,h):
            for c in range(3):
                tmp = int(img[j,i,c]*light + bias)
                if tmp > 255:
                    tmp = 255
                elif tmp < 0:
                    tmp = 0
                img[j,i,c] = tmp
    return img
 
#使用dlib自带的frontal_face_detector作为我们的特征提取器
detector = dlib.get_frontal_face_detector()
# 打开摄像头 参数为输入流，可以为摄像头或视频文件
camera = cv2.VideoCapture(0) #打开摄像头方式
#camera = cv2.VideoCapture('2.mp4') #采集视频的人脸

index = 1
while True:
    if (index <= 20):#存储20张人脸特征图像
        print('Being processed picture %s' % index)
        # 从摄像头读取照片
        success, img = camera.read()
        # 转为灰度图片
        gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        # 使用detector进行人脸检测
        dets = detector(gray_img, 1)
 
        for i, d in enumerate(dets):
            x1 = d.top() if d.top() > 0 else 0
            y1 = d.bottom() if d.bottom() > 0 else 0
            x2 = d.left() if d.left() > 0 else 0
            y2 = d.right() if d.right() > 0 else 0
 
            face = img[x1:y1,x2:y2]
            # 调整图片的对比度与亮度， 对比度与亮度值都取随机数，这样能增加样本的多样性
            face = relight(face, random.uniform(0.5, 1.5), random.randint(-50, 50))
 
            face = cv2.resize(face, (size,size))
 
            cv2.imshow('image', face)
 
            cv2.imwrite(output_dir+'/'+str(index)+'.jpg', face)
 
            index += 1
        key = cv2.waitKey(30) & 0xff
        if key == 27:
            break
    else:
        print('Finished!')
        # 释放摄像头 release camera
        camera.release()
        # 删除建立的窗口 delete all the windows
        cv2.destroyAllWindows()
        break
# Out:
# Being processed picture 1
# Being processed picture 2
# Being processed picture 3
# Being processed picture 4
# Being processed picture 5
# Being processed picture 6
# Being processed picture 7
# Being processed picture 8
# Being processed picture 9
# Being processed picture 10
# Being processed picture 11
# Being processed picture 12
# Being processed picture 13
# Being processed picture 14
# Being processed picture 15
# Being processed picture 16
# Being processed picture 17
# Being processed picture 18
# Being processed picture 19
# Being processed picture 20
# Finished!

# %%
from cv2 import cv2 as cv2
import os
import dlib
from skimage import io
import csv
import numpy as np
 
# 要读取人脸图像文件的路径
path_images_from_camera = "D:/face/631907060410/"

# Dlib 正向人脸检测器
detector = dlib.get_frontal_face_detector()

# Dlib 人脸预测器
predictor = dlib.shape_predictor("C:/Users/86150/JupyterProject/shape_predictor_68_face_landmarks.dat") #我这是在同一路径下的，shape_predictor_68_face_landmarks.dat不在同一路径的话
#要写为绝对路径："D:/****/****/shape_predictor_68_face_landmarks.dat"

# Dlib 人脸识别模型
# Face recognition model, the object maps human faces into 128D vectors
face_rec = dlib.face_recognition_model_v1("C:/Users/86150/JupyterProject/dlib_face_recognition_resnet_model_v1.dat")#我这是在同一路径下的，dlib_face_recognition_resnet_model_v1.dat不在
#要写为绝对路径："D:/****/****/dlib_face_recognition_resnet_model_v1.dat"

# 返回单张图像的 128D 特征
def return_128d_features(path_img):
    img_rd = io.imread(path_img)
    s=path_img
    a=s[21:22]
    i1=str(a)
    a1=s[24:]
    str1="/"
    b=a1[a1.index(str1):-4]
    b1=b[1:]
    i2=str(b1)
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_BGR2RGB)
    faces = detector(img_gray, 1)
    for i in range(len(faces)):
        landmarks = np.matrix([[p.x, p.y] for p in predictor(img_rd,faces[i]).parts()])  
        for idx, point in enumerate(landmarks):
            # 68点的坐标
            pos = (point[0, 0], point[0, 1])
            add="D:/face/631907060410/face"+i1+"_feature"+i2+".csv"
            with open(add, "a", newline="") as csvfile:
                writer1 = csv.writer(csvfile)
                writer1.writerow((idx,pos))
        print(add)
    print("%-40s %-20s" % ("检测到人脸的图像 / image with faces detected:", path_img), '\n')

    # 因为有可能截下来的人脸再去检测，检测不出来人脸了
    # 所以要确保是 检测到人脸的人脸图像 拿去算特征
    if len(faces) != 0:
        shape = predictor(img_gray, faces[0])
        face_descriptor = face_rec.compute_face_descriptor(img_gray, shape)
    else:
        face_descriptor = 0
        print("no face")

    return face_descriptor


# 将文件夹中照片特征提取出来, 写入 CSV
def return_features_mean_personX(path_faces_personX):
    features_list_personX = []
    s=path_faces_personX
    a=s[21:22]
    i2=str(a)
    photos_list = os.listdir(path_faces_personX)
    if photos_list:
        for i in range(len(photos_list)):
            # 调用return_128d_features()得到128d特征
            print("%-40s %-20s" % ("正在读的人脸图像 / image to read:", path_faces_personX + "/" + photos_list[i]))
            features_128d = return_128d_features(path_faces_personX + "/" + photos_list[i])
            #  print(features_128d)
            # 遇到没有检测出人脸的图片跳过
            if features_128d == 0:
                i += 1
            else:
                features_list_personX.append(features_128d)
                i1=str(i+1)
                add="D:/face/feature/"+i2+"feature"+i1+".csv"
                print(add)
                with open(add, "w", newline="") as csvfile:
                    writer1 = csv.writer(csvfile)
                    writer1.writerow(features_128d)


    else:
        print("文件夹内图像文件为空 / Warning: No images in " + path_faces_personX + '/', '\n')

    # 计算 128D 特征的均值
    # N x 128D -> 1 x 128D
    if features_list_personX:
        features_mean_personX = np.array(features_list_personX).mean(axis=0)
    else:
        features_mean_personX = '0'

    return features_mean_personX


# 读取某人所有的人脸图像的数据
people = os.listdir(path_images_from_camera)
people.sort()
with open("D:/face/631907060410/face_feature_mean.csv", "w", newline="") as csvfile: #程序会新建一个表格文件来保存特征值，方便以后比对
    writer = csv.writer(csvfile)
    for person in people:
        print("##### " + person + " #####")
        # Get the mean/average features of face/personX, it will be a list with a length of 128D
        features_mean_personX = return_features_mean_personX(path_images_from_camera + person)
        writer.writerow(features_mean_personX)
        print("特征均值 / The mean of features:", list(features_mean_personX))
        print('\n')
    print("所有录入人脸数据存入 / Save all the features of faces registered into: D:/631907060410face_feature_mean.csv")
# Out:
# ##### 2jeonghan #####
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/1.jpg
# D:/face/631907060410/face2_feature1.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/1.jpg
#
# D:/face/feature/2feature1.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/10.jpg
# D:/face/631907060410/face2_feature10.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/10.jpg
#
# D:/face/feature/2feature2.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/11.jpg
# D:/face/631907060410/face2_feature11.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/11.jpg
#
# D:/face/feature/2feature3.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/12.jpg
# D:/face/631907060410/face2_feature12.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/12.jpg
#
# D:/face/feature/2feature4.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/13.jpg
# D:/face/631907060410/face2_feature13.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/13.jpg
#
# D:/face/feature/2feature5.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/14.jpg
# D:/face/631907060410/face2_feature14.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/14.jpg
#
# D:/face/feature/2feature6.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/15.jpg
# D:/face/631907060410/face2_feature15.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/15.jpg
#
# D:/face/feature/2feature7.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/16.jpg
# D:/face/631907060410/face2_feature16.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/16.jpg
#
# D:/face/feature/2feature8.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/17.jpg
# D:/face/631907060410/face2_feature17.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/17.jpg
#
# D:/face/feature/2feature9.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/18.jpg
# D:/face/631907060410/face2_feature18.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/18.jpg
#
# D:/face/feature/2feature10.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/19.jpg
# D:/face/631907060410/face2_feature19.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/19.jpg
#
# D:/face/feature/2feature11.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/2.jpg
# D:/face/631907060410/face2_feature2.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/2.jpg
#
# D:/face/feature/2feature12.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/20.jpg
# D:/face/631907060410/face2_feature20.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/20.jpg
#
# D:/face/feature/2feature13.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/3.jpg
# D:/face/631907060410/face2_feature3.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/3.jpg
#
# D:/face/feature/2feature14.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/4.jpg
# D:/face/631907060410/face2_feature4.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/4.jpg
#
# D:/face/feature/2feature15.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/5.jpg
# D:/face/631907060410/face2_feature5.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/5.jpg
#
# D:/face/feature/2feature16.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/6.jpg
# D:/face/631907060410/face2_feature6.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/6.jpg
#
# D:/face/feature/2feature17.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/7.jpg
# D:/face/631907060410/face2_feature7.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/7.jpg
#
# D:/face/feature/2feature18.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/8.jpg
# D:/face/631907060410/face2_feature8.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/8.jpg
#
# D:/face/feature/2feature19.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/2jeonghan/9.jpg
# D:/face/631907060410/face2_feature9.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/2jeonghan/9.jpg
#
# D:/face/feature/2feature20.csv
# 特征均值 / The mean of features: [-0.11468229107558728, 0.08795658312737942, 0.06819434659555554, -0.09460258800536395, -0.16865972504019738, -0.06276720494497567, -0.10863393098115921, -0.10689989794045687, 0.1026158720254898, -0.09691338241100311, 0.20409194827079774, -0.07405817210674286, -0.1684294581413269, -0.01887833109940402, -0.053465938102453946, 0.18722159788012505, -0.19408487901091576, -0.14156200736761093, -0.022663502115756275, -0.02461456994060427, 0.04480105496477336, 0.05095282471738756, -0.008489805465796963, 0.035874821501784025, -0.11226819269359112, -0.32461118027567865, -0.07245320696383714, -0.05656991973519325, -0.0035447197500616313, -0.058622571546584366, -0.041389608010649684, 0.021290785737801344, -0.16715747267007827, -0.03617385867983103, 0.07655592523515224, 0.13047393038868904, 0.013259311014553531, -0.09298728164285422, 0.1394870661199093, -0.006136961723677814, -0.27328670099377633, 0.08852585088461637, 0.08869350682944059, 0.26710722148418425, 0.23293766677379607, -0.018861260294215754, 0.0010588956531137228, -0.18017918318510057, 0.1454970881342888, -0.1517805464565754, 0.025536842364817857, 0.12087542377412319, 0.033737877407111226, 0.022901014797389506, 0.005028762225992978, -0.11125939153134823, 0.024097602907568218, 0.1709648985415697, -0.1747271228581667, -0.01657782308757305, 0.12927961274981498, -0.05962892966344953, 0.0021771891973912717, -0.12473553791642189, 0.20518093481659888, 0.07406559041701258, -0.13054533377289773, -0.2113609194755554, 0.0966594960540533, -0.13183841183781625, -0.09723116140812635, 0.08402546402066946, -0.16249647960066796, -0.17160307466983796, -0.31268645972013476, 0.012559962831437588, 0.40919923335313796, 0.12400387674570083, -0.19100206047296525, 0.051481584925204514, -0.03998023180756718, 0.006523162126541138, 0.133285591006279, 0.16423271782696247, 0.032809455320239066, 0.012860645912587643, -0.0914029411971569, 0.030066230939701198, 0.2452034443616867, -0.05088332910090685, -0.03298348269890994, 0.18254543393850325, 0.010778259532526136, 0.05666515976190567, 0.013447594782337546, 0.06421882342547178, -0.12024715207517148, 0.0253518721787259, -0.18360874727368354, -0.06188872139900923, -0.021495859883725644, 0.005763783399015665, 0.004834025935269892, 0.15299365483224392, -0.1549725253134966, 0.1357274804264307, 0.01214068669360131, 0.006432461272925139, -0.028898357739672066, -0.01847666654502973, -0.0024983001872897147, -0.03749925880692899, 0.12355117239058018, -0.22019773796200753, 0.1815758153796196, 0.16732256785035132, 0.11489192694425583, 0.12784783579409123, 0.11000498682260514, 0.022647979110479353, -0.018102876329794525, -0.022952238842844964, -0.18380745723843575, 0.004223639647534583, 0.04176235764753074, -0.015619862289167941, 0.13738506585359572, 0.023405369301326574]
#
#
# ##### 4me #####
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/1.jpg
# D:/face/631907060410/face4_feature1.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/1.jpg
#
# D:/face/feature/4feature1.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/10.jpg
# D:/face/631907060410/face4_feature10.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/10.jpg
#
# D:/face/feature/4feature2.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/11.jpg
# D:/face/631907060410/face4_feature11.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/11.jpg
#
# D:/face/feature/4feature3.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/12.jpg
# D:/face/631907060410/face4_feature12.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/12.jpg
# D:/face/feature/4feature4.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/13.jpg
# D:/face/631907060410/face4_feature13.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/13.jpg
#
# D:/face/feature/4feature5.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/14.jpg
# D:/face/631907060410/face4_feature14.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/14.jpg
#
# D:/face/feature/4feature6.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/15.jpg
# D:/face/631907060410/face4_feature15.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/15.jpg
#
# D:/face/feature/4feature7.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/16.jpg
# D:/face/631907060410/face4_feature16.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/16.jpg
#
# D:/face/feature/4feature8.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/17.jpg
# D:/face/631907060410/face4_feature17.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/17.jpg
#
# D:/face/feature/4feature9.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/18.jpg
# D:/face/631907060410/face4_feature18.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/18.jpg
#
# D:/face/feature/4feature10.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/19.jpg
# D:/face/631907060410/face4_feature19.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/19.jpg
#
# D:/face/feature/4feature11.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/2.jpg
# D:/face/631907060410/face4_feature2.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/2.jpg
#
# D:/face/feature/4feature12.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/20.jpg
# D:/face/631907060410/face4_feature20.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/20.jpg
#
# D:/face/feature/4feature13.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/3.jpg
# D:/face/631907060410/face4_feature3.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/3.jpg
#
# D:/face/feature/4feature14.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/4.jpg
# D:/face/631907060410/face4_feature4.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/4.jpg
#
# D:/face/feature/4feature15.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/5.jpg
# D:/face/631907060410/face4_feature5.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/5.jpg
#
# D:/face/feature/4feature16.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/6.jpg
# D:/face/631907060410/face4_feature6.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/6.jpg
#
# D:/face/feature/4feature17.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/7.jpg
# D:/face/631907060410/face4_feature7.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/7.jpg
#
# D:/face/feature/4feature18.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/8.jpg
# D:/face/631907060410/face4_feature8.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/8.jpg
#
# D:/face/feature/4feature19.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/4me/9.jpg
# D:/face/631907060410/face4_feature9.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/4me/9.jpg
#
# D:/face/feature/4feature20.csv
# 特征均值 / The mean of features: [-0.07198233623057604, 0.014073191164061426, 0.05261365873739123, -0.09699110314249992, -0.17970659919083118, -0.03816386894322932, -0.1135683584958315, -0.07100899126380682, 0.15374939218163491, -0.1489350449293852, 0.1907795026898384, -0.06281269267201424, -0.16030343621969223, 0.005206328548956663, -0.08747368305921555, 0.21708093136548995, -0.14333075284957886, -0.14607561379671097, 0.012354309391230344, -0.018728045187890528, 0.053888965398073196, 0.0331525263376534, -0.04618733708630316, 0.06777898464351892, -0.10919381827116012, -0.29637071639299395, -0.08626203034073114, -0.12201258353888988, 0.0027152819093316793, -0.07992744445800781, 0.005176883609965444, 0.1502836685627699, -0.15430022701621054, 0.01373448669910431, 0.018783514201641083, 0.16135430112481117, 0.0559762361459434, -0.04034248683601618, 0.09060556963086128, 0.025684552104212343, -0.29351537525653837, 0.008116764458827674, 0.0596716474276036, 0.23426348716020584, 0.1494504153728485, 0.015776368021033705, 0.02521380502730608, -0.10824983399361372, 0.10168378241360188, -0.18699437230825425, 0.05697924979031086, 0.07786587998270988, 0.07985116355121136, 0.052131546661257744, 0.029604507400654255, -0.13165412209928035, 0.09809304140508175, 0.07465389370918274, -0.18077124878764153, 0.031990896922070536, 0.14798754546791315, -0.050482836365699765, 0.04016960123553872, -0.07651936691254377, 0.25726435482501986, 0.07888865021523088, -0.11546370498836041, -0.13724427185952665, 0.1508788738399744, -0.17158324643969536, -0.13306506350636482, 0.06088104471564293, -0.1345401592552662, -0.11126483790576458, -0.34853999614715575, -0.01957176495343447, 0.44528752863407134, 0.12770315296947957, -0.15329980254173278, 0.08514997586607934, -0.03546352237462998, -0.03146187686361372, 0.09073572806082666, 0.1526410523802042, 0.018694290798157452, 0.003821028210222721, -0.06610052715986967, -0.01263885824009776, 0.256818987429142, -0.0381126238964498, 0.01871614749543369, 0.17758133858442307, -0.025021220324561, 0.058744698436930774, -0.024475168203935027, 0.0586218049749732, -0.062044281885027884, 0.01915269091259688, -0.076565583050251, -0.005273036076687276, -0.07628190070390702, -0.04927493669092655, -0.041047069057822225, 0.11803594008088111, -0.19128487557172774, 0.1469503052532673, -0.007259307871572673, 0.01037091384641826, -0.01711868392303586, 0.10536659397184849, -0.08056368380784988, -0.04996535442769527, 0.15657839104533194, -0.21259379312396048, 0.18324679881334305, 0.1614840179681778, 0.10756665589287877, 0.09914113841950893, 0.11303531117737294, 0.10943344794213772, -0.022028471948578952, -0.08411949630826712, -0.2056953564286232, -0.048761491943150756, 0.04982744986191392, -0.0979520108550787, 0.03294707490131259, 0.08698109202086926]
#
#
# ##### 5xiaoyeping #####
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/1.jpg
# D:/face/631907060410/face5_feature1.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/1.jpg
#
# D:/face/feature/5feature1.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/10.jpg
# D:/face/631907060410/face5_feature10.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/10.jpg
#
# D:/face/feature/5feature2.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/11.jpg
# D:/face/631907060410/face5_feature11.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/11.jpg
#
# D:/face/feature/5feature3.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/12.jpg
# D:/face/631907060410/face5_feature12.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/12.jpg
#
# D:/face/feature/5feature4.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/13.jpg
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/13.jpg
#
# no face
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/14.jpg
# D:/face/631907060410/face5_feature14.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/14.jpg
#
# D:/face/feature/5feature6.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/15.jpg
# D:/face/631907060410/face5_feature15.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/15.jpg
#
# D:/face/feature/5feature7.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/16.jpg
# D:/face/631907060410/face5_feature16.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/16.jpg
#
# D:/face/feature/5feature8.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/17.jpg
# D:/face/631907060410/face5_feature17.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/17.jpg
# D:/face/feature/5feature9.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/18.jpg
# D:/face/631907060410/face5_feature18.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/18.jpg
#
# D:/face/feature/5feature10.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/19.jpg
# D:/face/631907060410/face5_feature19.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/19.jpg
#
# D:/face/feature/5feature11.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/2.jpg
# D:/face/631907060410/face5_feature2.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/2.jpg
#
# D:/face/feature/5feature12.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/20.jpg
# D:/face/631907060410/face5_feature20.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/20.jpg
#
# D:/face/feature/5feature13.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/3.jpg
# D:/face/631907060410/face5_feature3.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/3.jpg
#
# D:/face/feature/5feature14.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/4.jpg
# D:/face/631907060410/face5_feature4.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/4.jpg
#
# D:/face/feature/5feature15.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/5.jpg
# D:/face/631907060410/face5_feature5.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/5.jpg
#
# D:/face/feature/5feature16.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/6.jpg
# D:/face/631907060410/face5_feature6.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/6.jpg
#
# D:/face/feature/5feature17.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/7.jpg
# D:/face/631907060410/face5_feature7.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/7.jpg
#
# D:/face/feature/5feature18.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/8.jpg
# D:/face/631907060410/face5_feature8.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/8.jpg
#
# D:/face/feature/5feature19.csv
# 正在读的人脸图像 / image to read:                D:/face/631907060410/5xiaoyeping/9.jpg
# D:/face/631907060410/face5_feature9.csv
# 检测到人脸的图像 / image with faces detected:    D:/face/631907060410/5xiaoyeping/9.jpg
#
# D:/face/feature/5feature20.csv
# 特征均值 / The mean of features: [-0.1256689711620933, 0.08753596128601777, 0.024476057898841407, -0.09200770996118847, -0.19212925355685384, -0.035924048015945835, -0.06636900768468254, -0.12842331512978203, 0.12714184036380366, -0.10820443653746654, 0.17103771630086398, -0.05628956001448004, -0.19302145195634743, -0.056632016638391895, -0.025574896116986087, 0.20152452509654195, -0.13147950760628047, -0.14190304553822466, -0.018723729017533754, -0.05309119330425011, 0.004767082509045538, 0.0819754988739365, 0.012771727835857555, 0.014234786130193817, -0.15912174472683355, -0.34155687062363876, -0.07177737639530708, -0.042244615131302884, -0.04298844330601002, -0.0165720234600533, 0.009046766392298435, 0.12518589159375743, -0.15012172491926895, -0.045573199363915545, 0.08583447611645649, 0.11992566287517548, -0.036740979620892754, -0.04479470045158738, 0.13598446665625824, 0.0035547851094681966, -0.2341355148114656, 0.0034116420674284824, 0.10736943997050587, 0.308651991580662, 0.15589050478056857, -0.0009918989105101087, 0.043783728033304214, -0.108669686866434, 0.12207898144659243, -0.14938512993486305, -0.018491460794680996, 0.09097312077095634, -0.003045779763181743, 0.01070885181328968, 0.018439000496934903, -0.09360326826572418, 0.06804908459123812, 0.14063964235155205, -0.1604998629344137, -0.012151275295764208, 0.13099378033688194, -0.0937586383599984, -0.07421145666586726, -0.12077700778057701, 0.2360001990669652, 0.039843698767455, -0.11644547981651206, -0.17311802506446838, 0.08934853343587172, -0.12631142296289144, -0.11623942303030114, 0.022467771447018572, -0.1607313650219064, -0.15227537249263964, -0.32564622634335566, -0.02806022439740206, 0.37416893871206985, 0.09726460121179882, -0.14164977050141284, 0.08522519626115498, 0.030588280850727307, 0.025878622956377894, 0.12801583464208402, 0.15703934352648885, 0.0049632609772839046, 0.005400303261060464, -0.062284234911203384, 0.015928648265176697, 0.23984416064463163, -0.06072462595214969, -0.01764940186158607, 0.1873198473139813, 0.019297998447559382, 0.0545921200200131, 0.0015720037596398278, 0.028050056199151043, -0.09816904091521313, 0.04385875846798483, -0.11267297362026416, 0.005207890105482779, 0.04040755983442068, -0.05507284814589902, 0.027869884267841514, 0.13432756772166804, -0.19324163151414772, 0.20639081377732127, 0.011547589172167997, 0.07246422375503339, 0.022098159687103408, -0.002132316420197879, -0.04855800625917159, -0.039111652313486525, 0.11829238032039843, -0.21106994701059242, 0.16347165837099678, 0.18346910649224332, 0.05052805740974451, 0.13688535556981438, 0.11677989481311095, 0.0313526510604118, -0.023857079887468564, 0.048851103374832554, -0.21086399492464566, -0.05073731441638971, 0.06886137551382969, -0.0879347343978129, 0.0871688423580245, 0.04554056787961408]
#
#
# 所有录入人脸数据存入 / Save all the features of faces registered into: D:/631907060410face_feature_mean.csv

# %%
import os
import winsound # 系统音效
from playsound import playsound # 音频播放
import dlib          # 人脸处理的库 Dlib
import csv # 存入表格
import time
import sys
import numpy as np   # 数据处理的库 numpy
from cv2 import cv2 as cv2           # 图像处理的库 OpenCv
import pandas as pd  # 数据处理的库 Pandas


# 人脸识别模型，提取128D的特征矢量
# face recognition model, the object maps human faces into 128D vectors
# Refer this tutorial: http://dlib.net/python/index.html#dlib.face_recognition_model_v1
facerec = dlib.face_recognition_model_v1("C:/Users/86150/JupyterProject/dlib_face_recognition_resnet_model_v1.dat")#我这是在同一路径下的，dlib_face_recognition_resnet_model_v1.dat不在
#要写为绝对路径："D:/****/****/dlib_face_recognition_resnet_model_v1.dat"


# 计算两个128D向量间的欧式距离
# compute the e-distance between two 128D features
def return_euclidean_distance(feature_1, feature_2):
    feature_1 = np.array(feature_1)
    feature_2 = np.array(feature_2)
    dist = np.sqrt(np.sum(np.square(feature_1 - feature_2)))
    return dist


# 处理存放所有人脸特征的 csv
path_features_known_csv = "D:/face/631907060410/face_feature_mean.csv"
csv_rd = pd.read_csv(path_features_known_csv, header=None)


# 用来存放所有录入人脸特征的数组
# the array to save the features of faces in the database
features_known_arr = []

# 读取已知人脸数据
# print known faces
for i in range(csv_rd.shape[0]):
    features_someone_arr = []
    for j in range(0, len(csv_rd.ix[i, :])):
        features_someone_arr.append(csv_rd.ix[i, :][j])
    features_known_arr.append(features_someone_arr)
print("Faces in Database：", len(features_known_arr))

# Dlib 检测器和预测器
# The detector and predictor will be used
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('C:/Users/86150/JupyterProject/shape_predictor_68_face_landmarks.dat')#我这是在同一路径下的，shape_predictor_68_face_landmarks.dat不在
#要写为绝对路径："D:/****/****/shape_predictor_68_face_landmarks.dat

# 创建 cv2 摄像头对象
# cv2.VideoCapture(0) to use the default camera of PC,
# and you can use local video name by use cv2.VideoCapture(filename)
cap = cv2.VideoCapture(0)

# cap.set(propId, value)
# 设置视频参数，propId 设置的视频参数，value 设置的参数值
cap.set(3, 480)

# cap.isOpened() 返回 true/false 检查初始化是否成功
# when the camera is open
while cap.isOpened():

    flag, img_rd = cap.read()
    kk = cv2.waitKey(1)

    # 取灰度
    img_gray = cv2.cvtColor(img_rd, cv2.COLOR_RGB2GRAY)

    # 人脸数 faces
    faces = detector(img_gray, 0)

    # 待会要写的字体 font to write later
    font = cv2.FONT_HERSHEY_COMPLEX

    # 存储当前摄像头中捕获到的所有人脸的坐标/名字
    # the list to save the positions and names of current faces captured
    pos_namelist = []
    name_namelist = []

    # 按下 q 键退出
    # press 'q' to exit
    if kk == ord('q'):
        break
    else:
        # 检测到人脸 when face detected
        if len(faces) != 0:  
            # 获取当前捕获到的图像的所有人脸的特征，存储到 features_cap_arr
            # get the features captured and save into features_cap_arr
            features_cap_arr = []
            for i in range(len(faces)):
                shape = predictor(img_rd, faces[i])
                features_cap_arr.append(facerec.compute_face_descriptor(img_rd, shape))

            # 遍历捕获到的图像中所有的人脸
            # traversal all the faces in the database
            for k in range(len(faces)):
                print("##### camera person", k+1, "#####")
                # 让人名跟随在矩形框的下方
                # 确定人名的位置坐标
                # 先默认所有人不认识，是 unknown
                # set the default names of faces with "unknown"
                name_namelist.append("unknown")

                # 每个捕获人脸的名字坐标 the positions of faces captured
                pos_namelist.append(tuple([faces[k].left(), int(faces[k].bottom() + (faces[k].bottom() - faces[k].top())/4)]))

                # 对于某张人脸，遍历所有存储的人脸特征
                # for every faces detected, compare the faces in the database
                e_distance_list = []
                for i in range(len(features_known_arr)):
                    # 如果 person_X 数据不为空
                    if str(features_known_arr[i][0]) != '0.0':
                        print("with person", str(i + 1), "the e distance: ", end='')
                        e_distance_tmp = return_euclidean_distance(features_cap_arr[k], features_known_arr[i])
                        print(e_distance_tmp)
                        e_distance_list.append(e_distance_tmp)
                    else:
                        # 空数据 person_X
                        e_distance_list.append(999999999)
                # 找出最接近的一个人脸数据是第几个
                # Find the one with minimum e distance
                similar_person_num = e_distance_list.index(min(e_distance_list))
                print("Minimum e distance with person", int(similar_person_num)+1)
                
                # 计算人脸识别特征与数据集特征的欧氏距离
                # 距离小于0.4则标出为可识别人物
                if min(e_distance_list) < 0.4:
                    # 这里可以修改摄像头中标出的人名
                    # Here you can modify the names shown on the camera
                    # 1、遍历文件夹目录
                    folder_name = 'D:/face/631907060410'
                    # 最接近的人脸
                    sum=similar_person_num+1
                    key_id=1 # 从第一个人脸数据文件夹进行对比
                    # 获取文件夹中的文件名:1wang、2zhou、3...
                    file_names = os.listdir(folder_name)
                    for name in file_names:
                        # print(name+'->'+str(key_id))
                        if sum ==key_id:
                            #winsound.Beep(300,500)# 响铃：300频率，500持续时间
                            name_namelist[k] = name[1:]#人名删去第一个数字（用于视频输出标识）
                        key_id += 1
                    # 播放欢迎光临音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/welcome.wav')
                    # print("May be person "+str(int(similar_person_num)+1))
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor人脸图像文件的路径
                        path_visitors_save_dir = "D:/face/known" #自己在faces路径下先建一个known文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40wang.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        save_name = str(now_time)+str(name_namelist[k])+'.jpg'
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ save_name    
                        # 遍历visitor文件夹所有文件名
                        visitor_names = os.listdir(path_visitors_save_dir)
                        visitor_name=''
                        for name in visitor_names:
                            # 名字切片到分钟数：2019-06-26-11-33-00wangyu.jpg
                            visitor_name=(name[0:16]+'-00'+name[19:])
                        # print(visitor_name)
                        visitor_save=(save_name[0:16]+'-00'+save_name[19:])
                        # print(visitor_save)
                        # 一分钟之内重复的人名不保存
                        if visitor_save!=visitor_name:
                            cv2.imwrite(save_path, face)
                            print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+str(name_namelist[k])+'.jpg')
                        else:
                            print('重复，未保存！')
                            
                else:
                    # 播放无法识别音效
                    #playsound('D:/myworkspace/JupyterNotebook/People/music/sorry.wav')
                    print("Unknown person")
                    # -----保存图片-------
                    # -----------筛选出人脸并保存到visitor文件夹------------
                    for i, d in enumerate(faces):
                        x1 = d.top() if d.top() > 0 else 0
                        y1 = d.bottom() if d.bottom() > 0 else 0
                        x2 = d.left() if d.left() > 0 else 0
                        y2 = d.right() if d.right() > 0 else 0
                        face = img_rd[x1:y1,x2:y2]
                        size = 64
                        face = cv2.resize(face, (size,size))
                        # 要存储visitor-》unknown人脸图像文件的路径
                        path_visitors_save_dir = "D:/face/unknown"#自己在faces路径下先建一个unknown文件，否则可能会报错
                        # 存储格式：2019-06-24-14-33-40unknown.jpg
                        now_time = time.strftime("%Y-%m-%d-%H-%M-%S", time.localtime())
                        # print(save_name)
                        # 本次图片保存的完整url
                        save_path = path_visitors_save_dir+'/'+ str(now_time)+'unknown.jpg'
                        cv2.imwrite(save_path, face)
                        print('新存储：'+path_visitors_save_dir+'/'+str(now_time)+'unknown.jpg')
                
                # 矩形框
                # draw rectangle
                for kk, d in enumerate(faces):
                    # 绘制矩形框
                    cv2.rectangle(img_rd, tuple([d.left(), d.top()]), tuple([d.right(), d.bottom()]), (0, 255, 255), 2)
                print('\n')

            # 在人脸框下面写人脸名字
            # write names under rectangle
            for i in range(len(faces)):
                cv2.putText(img_rd, name_namelist[i], pos_namelist[i], font, 0.8, (0, 255, 255), 1, cv2.LINE_AA)

    print("Faces in camera now:", name_namelist, "\n")

    #cv2.putText(img_rd, "Press 'q': Quit", (20, 450), font, 0.8, (84, 255, 159), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Face Recognition", (20, 40), font, 1, (0, 0, 255), 1, cv2.LINE_AA)
    cv2.putText(img_rd, "Visitors: " + str(len(faces)), (20, 100), font, 1, (0, 0, 255), 1, cv2.LINE_AA)

    # 窗口显示 show with opencv
    cv2.imshow("camera", img_rd)
    k = cv2.waitKey(1)
    if k == 27:    # press 'ESC' to quit
        break
# 释放摄像头 release camera
cap.release()

# 删除建立的窗口 delete all the windows
cv2.destroyAllWindows()
# Out:
# C:\Users\86150\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\86150\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# Faces in Database： 3
# ##### camera person 1 #####
# with person 1 the e distance: 0.3558615688103717
# with person 2 the e distance: 0.5795829506263812
# with person 3 the e distance: 0.5263582163299368
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.35075959925747996
# with person 2 the e distance: 0.5718290207981878
# with person 3 the e distance: 0.4881930228174718
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.33747714703521503
# with person 2 the e distance: 0.5890956385482593
# with person 3 the e distance: 0.5091924943621273
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.342868870008931
# with person 2 the e distance: 0.5901616565773306
# with person 3 the e distance: 0.4970370215835402
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3478258524694968
# with person 2 the e distance: 0.5900768021286052
# with person 3 the e distance: 0.5206749894668908
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3345298852556077
# with person 2 the e distance: 0.5833199245360496
# with person 3 the e distance: 0.49433917645995756
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3503980842681365
# with person 2 the e distance: 0.5950540119843363
# with person 3 the e distance: 0.5043715969248258
# Minimum e distance with person 1
# 新存储：D:/face/known/2021-11-13-22-22-00jeonghan.jpg
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34674653375920633
# with person 2 the e distance: 0.5862776345575423
# with person 3 the e distance: 0.4968775763263301
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3550399741639085
# with person 2 the e distance: 0.5854988472394416
# with person 3 the e distance: 0.501174759258547
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36185904725601514
# with person 2 the e distance: 0.5794695524541977
# with person 3 the e distance: 0.5084465110911576
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.36010269594852506
# with person 2 the e distance: 0.5870010533847521
# with person 3 the e distance: 0.49991597907755403
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3496457281598575
# with person 2 the e distance: 0.5830454515195221
# with person 3 the e distance: 0.5059197344940733
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.3661368332615928
# with person 2 the e distance: 0.5825713294007058
# with person 3 the e distance: 0.5219785634492683
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
#
# ##### camera person 1 #####
# with person 1 the e distance: 0.34999900715844173
# with person 2 the e distance: 0.5806850246118103
# with person 3 the e distance: 0.5051654418273765
# Minimum e distance with person 1
# 重复，未保存！
#
#
# Faces in camera now: ['jeonghan']
